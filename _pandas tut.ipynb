# %%
# importing the pandas library
import pandas as pd

# %%
# creating a panda dataframe

# import the boston house price data

from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
# pandas dataframe

housing_df = pd.DataFrame(housing.data, columns=housing.feature_names)

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# import csv file to pandas dataframe

diabetes_df = pd.read_csv(r"C:\Users\ajays\OneDrive\Desktop\ML\datasets\diabetes.csv")

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %%
# loading the data from excel file into pandas dataframe

""""pd.read_excel('file path')"""

# Exporting dataframe to csv file

"""boston_df.to_csv('file path')"""

# %%
# exporting dataframe to excel file

random_df = pd.DataFrame(np.random.rand(20,10))

random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.785804  0.434565  0.900102  0.047256  0.096702  0.027944  0.764945
# 1  0.210234  0.482191  0.918583  0.715361  0.594843  0.423214  0.575777
# 2  0.847537  0.443265  0.732418  0.518639  0.004846  0.651638  0.337517
# 3  0.588085  0.545678  0.544854  0.505653  0.388458  0.099276  0.009252
# 4  0.378523  0.067646  0.000079  0.672672  0.615051  0.000885  0.306436
#
#           7         8         9
# 0  0.508178  0.712291  0.719266
# 1  0.247118  0.060766  0.181775
# 2  0.179463  0.325807  0.798661
# 3  0.473464  0.703857  0.880988
# 4  0.304879  0.499409  0.351352

# %%
random_df.shape
# Out:
# (20, 10)

# %%
print(housing_df.shape)
print(housing_df.head())
print(housing_df.tail())
print(housing_df.info())
print(housing_df.isnull().sum())
# Out:
# (20640, 8)
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# ...

# %%
# counting the values based on labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
# group the values based on the mean

diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
# Statistical Measures

# count of values

housing_df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
# mean value
housing_df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
# standard deviation
housing_df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
# maximum value
housing_df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
# all the statistical measures in 
housing_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
 # adding a column to dataframe
# df_name['new_column'] = dataset-name.target
housing_df['Price'] = housing.target

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
housing_df.drop(columns='MedInc',axis=1)
# Out:
#        HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0          41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1          21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2          52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3          52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4          52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...         ...       ...        ...         ...       ...       ...
# 20635      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# ...

# %%
# locating a row using the index value

housing_df.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# Price           3.521000
# Name: 2, dtype: float64

# %%
housing_df = housing_df.drop(columns='MedInc',axis=1)

# %%
housing_df.head()
# Out:
#    HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude  \
# 0      41.0  6.984127   1.023810       322.0  2.555556     37.88    -122.23
# 1      21.0  6.238137   0.971880      2401.0  2.109842     37.86    -122.22
# 2      52.0  8.288136   1.073446       496.0  2.802260     37.85    -122.24
# 3      52.0  5.817352   1.073059       558.0  2.547945     37.85    -122.25
# 4      52.0  6.281853   1.081081       565.0  2.181467     37.85    -122.25
#
#    Price
# 0  4.526
# 1  3.585
# 2  3.521
# 3  3.413
# 4  3.422

# %%
print(housing_df.iloc[:,0])
print(housing_df.iloc[:,1])
print(housing_df.iloc[:,2])
print(housing_df.iloc[:,-1])
# Out:
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64
# 0        6.984127
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
#            ...
# 20635    5.045455
# 20636    6.114035
# 20637    5.205543
# 20638    5.329513
# 20639    5.254717
# Name: AveRooms, Length: 20640, dtype: float64
# 0        1.023810
# 1        0.971880
# 2        1.073446
# 3        1.073059
# 4        1.081081
#            ...
# 20635    1.133333
# 20636    1.315789
# 20637    1.120092
# 20638    1.171920
# 20639    1.162264
# Name: AveBedrms, Length: 20640, dtype: float64
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: Price, Length: 20640, dtype: float64

# %%
print(housing_df.iloc[:,:1]) # print 1st column
print(housing_df.iloc[:,1:]) # print all columns except 1st
print(housing_df.iloc[:,:-1]) # print all except last
print(housing_df.iloc[:,-1:]) # print last column
# Out:
#        HouseAge
# 0          41.0
# 1          21.0
# 2          52.0
# 3          52.0
# 4          52.0
# ...         ...
# 20635      25.0
# 20636      18.0
# 20637      17.0
# 20638      18.0
# 20639      16.0
#
# [20640 rows x 1 columns]
#        AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude  Price
# 0      6.984127   1.023810       322.0  2.555556     37.88    -122.23  4.526
# 1      6.238137   0.971880      2401.0  2.109842     37.86    -122.22  3.585
# 2      8.288136   1.073446       496.0  2.802260     37.85    -122.24  3.521
# 3      5.817352   1.073059       558.0  2.547945     37.85    -122.25  3.413
# 4      6.281853   1.081081       565.0  2.181467     37.85    -122.25  3.422
# ...         ...        ...         ...       ...       ...        ...    ...
# 20635  5.045455   1.133333       845.0  2.560606     39.48    -121.09  0.781
# 20636  6.114035   1.315789       356.0  3.122807     39.49    -121.21  0.771
# ...

# %%
# correlation
'''  1. Positive
     2. Negative
'''
# Out:
# '  1. Positive\n     2. Negative\n'

# %%
housing_df.corr()
# Out:
#             HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# HouseAge    1.000000 -0.153277  -0.077747   -0.296244  0.013191  0.011173
# AveRooms   -0.153277  1.000000   0.847621   -0.072213 -0.004852  0.106389
# AveBedrms  -0.077747  0.847621   1.000000   -0.066197 -0.006181  0.069721
# Population -0.296244 -0.072213  -0.066197    1.000000  0.069863 -0.108785
# AveOccup    0.013191 -0.004852  -0.006181    0.069863  1.000000  0.002366
# Latitude    0.011173  0.106389   0.069721   -0.108785  0.002366  1.000000
# Longitude  -0.108197 -0.027540   0.013344    0.099773  0.002476 -0.924664
# Price       0.105623  0.151948  -0.046701   -0.024650 -0.023737 -0.144160
#
#             Longitude     Price
# HouseAge    -0.108197  0.105623
# AveRooms    -0.027540  0.151948
# AveBedrms    0.013344 -0.046701
# Population   0.099773 -0.024650
# AveOccup     0.002476 -0.023737
# Latitude    -0.924664 -0.144160
# Longitude    1.000000 -0.045967
# Price       -0.045967  1.000000
